# %% [markdown]
# # Paper results

# %%
def plot_v3_fig1(scenario_dir, scenario_tag, physics):
    pass

def plot_v3_fig2():
    pass

# %%
scenarios_dir = [
    "/Users/amal/Documents/research_code/CUQI-DTU/Collab-BrainEfflux-Data/A_Considered_for_the_paper/results_dec1",
    ]
scenarios_tag = [
    ["paperV4CARealDiff_Gauess_gibbs_scale_all7","paperV4CARealAdvDiff_Gauess_gibbs_scale_all7"]
    ]
num_scenarios = len(scenarios_dir)
figs_to_plot = [[1]]*num_scenarios
physics = [['diffusion', 'advection-diffusion']]*num_scenarios

for i in range(num_scenarios):
    if 1 in figs_to_plot[i]:
        plot_v3_fig1(scenarios_dir[i], scenarios_tag[i], physics[i])
    if 2 in figs_to_plot[i]:
        plot_v3_fig2(scenarios_dir[i], scenarios_tag[i], physics[i])
